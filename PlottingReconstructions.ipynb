# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
import h5py
# %matplotlib inline

# %% [markdown]
# ### n2e7

# %%
x = np.load('cell/ptychography/n2e7/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("n2e7.png")

# %% [markdown]
# ### 32x32cropped_baseline

# %%
x = np.load('cell/ptychography/32x32cropped_baseline/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32cropped_baseline.png")

# %% [markdown]
# ### 32x32croppedZS_baseline

# %%
x = np.load('cell/ptychography/32x32croppedZS_baseline/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32croppedZS_baseline.png")

# %% [markdown]
# ### 32x32merged_baseline

# %%
x = np.load('cell/ptychography/32x32merged_baseline/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32merged_baseline.png")

# %% [markdown]
# ### 32x32mergedZS_baseline

# %%
x = np.load('cell/ptychography/32x32mergedZS_baseline/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32mergedZS_baseline.png")

# %% [markdown]
# ### 32x32cropped_relu

# %%
x = np.load('cell/ptychography/32x32cropped_relu/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32cropped_relu.png")

# %% [markdown]
# ### 32x32croppedZS_relu

# %%
x = np.load('cell/ptychography/32x32croppedZS_relu/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32croppedZS_relu.png")

# %% [markdown]
# ### 32x32merged_relu

# %%
x = np.load('cell/ptychography/32x32merged_relu/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32merged_relu.png")

# %% [markdown]
# ### 32x32mergedZS_relu

# %%
x = np.load('cell/ptychography/32x32mergedZS_relu/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("32x32mergedZS_relu.png")

# %% [markdown]
# ### 72x72_baseline

# %%
x = np.load('cell/ptychography/72x72_baseline/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)
#im.set_clim(0,0.12)

plt.savefig("72x72_baseline.png")

# %% [markdown]
# ### 72x72ZS_baseline

# %%
x = np.load('cell/ptychography/72x72ZS_baseline/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)
#im.set_clim(0,0.12)

plt.savefig("72x72ZS_baseline.png")

# %% [markdown]
# ### 72x72_relu

# %%
x = np.load('cell/ptychography/72x72_relu/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)
#im.set_clim(0,0.12)

plt.savefig("72x72_relu.png")

# %% [markdown]
# ### 72x72ZS_relu

# %%
x = np.load('cell/ptychography/72x72ZS_relu/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)
#im.set_clim(0,0.12)

plt.savefig("72x72ZS_relu.png")

# %% [markdown]
# ### AE_72x72

# %%
x = np.load('cell/ptychography/AE_72x72/obj_checkpoint.npy')
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(x[:,:,0,0])
fig.colorbar(im, ax=ax)

plt.savefig("AE_72x72.png")
